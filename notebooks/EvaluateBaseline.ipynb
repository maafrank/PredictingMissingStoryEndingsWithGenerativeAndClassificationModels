# %%
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
import os
import pandas as pd
import numpy as np

# Ensure pandas prints the entire col
pd.set_option('display.max_colwidth', None)

# Load the combined narrative data
data_dir = '/content/drive/MyDrive/Colab Notebooks/Berkeley/266/FinalProject/Data/'
original_data = os.path.join(data_dir, 'ROCStories__spring2016 - ROCStories_spring2016.csv')

original_df = pd.read_csv(original_data)
batch_size = 5
original_df = original_df.iloc[batch_size:].head(5000)

mistral_df = pd.read_csv(os.path.join(data_dir, 'generated_narratives_mistral.csv'))
llama_df = pd.read_csv(os.path.join(data_dir, 'generated_narratives_llama.csv'))

# Fix Nan to ""
original_df = original_df.fillna("")
mistral_df = mistral_df.fillna("")
llama_df = llama_df.fillna("")

display(original_df.head())
display(mistral_df.head())
display(llama_df.head())

print(original_df.shape)
print(mistral_df.shape)
print(llama_df.shape)
# Out:
#                                 storyid           storytitle  \
# 5  5d5e7aeb-332f-4c8b-a3c3-44585501e493        Foolish Frank
# 6  bdceebb0-c6e8-417f-b6ae-741a0a71fcd3      Shark Adventure
# 7  a4a9aaca-d3d4-46b4-807c-ef75aea68c56  Too sunny for Sunny
# 8  8ddc9d26-d253-4eb3-b621-9a4e6d9c57e0      The Merry Widow
# 9  80ff5d8f-bcb1-437b-9da1-71c52997def2           Golf Cheat
#
#                                                sentence1  \
# 5                          Frank had been drinking beer.
# 6                   Dave was in the Bahamas on vacation.
# 7                      Sunny enjoyed going to the beach.
# 8  Sally was happy when her widowed mom found a new man.
# 9               Dan hit his golf ball and watched it go.
#
#                                                            sentence2  \
# 5            He got a call from his girlfriend, asking where he was.
# 6                     He decided to go snorkeling on his second day.
# 7  As she stepped out of her car, she realized she forgot something.
# 8                  She discovered her siblings didn't feel the same.
# 9              The ball bounced on the grass and into the sand trap.
#
#                                                    sentence3  \
# 5          Frank suddenly realized he had a date that night.
# 6                  While snorkeling, he saw a cave up ahead.
# 7          It was quite sunny and she forgot her sunglasses.
# 8     Sally flew to visit her mom and her mom's new husband.
# 9  Dan pretended that his ball actually landed on the green.
#
#                                                               sentence4  \
# 5              Since Frank was already a bit drunk, he could not drive.
# 6    He went into the cave, and he was terrified when he found a shark!
# 7             Sunny got back into her car and heading towards the mall.
# 8  Although her mom was obviously in love, he was nothing like her dad.
# 9           His friends were not paying attention so they believed him.
#
#                                                                 sentence5
# 5                  Frank spent the rest of the night drinking more beers.
# 6  Dave swam away as fast as he could, but the shark caught and ate Dave.
# 7               Sunny found some sunglasses and headed back to the beach.
# 8               Sally went home and wondered about her parents' marriage.
# 9           Dan snuck a ball on the green and made his putt from 10 feet.
#                                                sentence1  \
# 0                          Frank had been drinking beer.
# 1                   Dave was in the Bahamas on vacation.
# 2                      Sunny enjoyed going to the beach.
# 3  Sally was happy when her widowed mom found a new man.
# 4               Dan hit his golf ball and watched it go.
#
#                                                            sentence2  \
# 0            He got a call from his girlfriend, asking where he was.
# 1                     He decided to go snorkeling on his second day.
# 2  As she stepped out of her car, she realized she forgot something.
# 3                  She discovered her siblings didn't feel the same.
# 4              The ball bounced on the grass and into the sand trap.
#
#                                                    sentence3  \
# 0          Frank suddenly realized he had a date that night.
# 1                  While snorkeling, he saw a cave up ahead.
# 2          It was quite sunny and she forgot her sunglasses.
# 3     Sally flew to visit her mom and her mom's new husband.
# 4  Dan pretended that his ball actually landed on the green.
#
#                                                               sentence4  \
# 0              Since Frank was already a bit drunk, he could not drive.
# 1    He went into the cave, and he was terrified when he found a shark!
# 2             Sunny got back into her car and heading towards the mall.
# 3  Although her mom was obviously in love, he was nothing like her dad.
# 4           His friends were not paying attention so they believed him.
#
#                                                                                                                                                                                                         sentence5
# 0                                                                                                                Frank called an Uber and was able to make it to his date on time, apologizing for his tardiness.
# 1                                                                                Dave quickly swam back to the surface, scared out of his wits. He decided to head back to shore and avoid the cave from then on.
# 2                                                           Sunny bought a new pair of sunglasses at the mall, but they were too expensive. She decided to save up for a while before she could get another pair.
# 3                                    Although Sally struggled at first, she eventually accepted that her mom's new partner was not like her late father. She promised to support her mom in her new relationship.
# 4  Dan's friends eventually noticed that his ball had not landed on the green and confronted him. Dan reluctantly confessed to his lie and made a resolution to always be honest on the golf course from then on.
#                                                sentence1  \
# 0                          Frank had been drinking beer.
# 1                   Dave was in the Bahamas on vacation.
# 2                      Sunny enjoyed going to the beach.
# 3  Sally was happy when her widowed mom found a new man.
# 4               Dan hit his golf ball and watched it go.
#
#                                                            sentence2  \
# 0            He got a call from his girlfriend, asking where he was.
# 1                     He decided to go snorkeling on his second day.
# 2  As she stepped out of her car, she realized she forgot something.
# 3                  She discovered her siblings didn't feel the same.
# 4              The ball bounced on the grass and into the sand trap.
#
#                                                    sentence3  \
# 0          Frank suddenly realized he had a date that night.
# 1                  While snorkeling, he saw a cave up ahead.
# 2          It was quite sunny and she forgot her sunglasses.
# 3     Sally flew to visit her mom and her mom's new husband.
# 4  Dan pretended that his ball actually landed on the green.
#
#                                                               sentence4  \
# 0              Since Frank was already a bit drunk, he could not drive.
# 1    He went into the cave, and he was terrified when he found a shark!
# 2             Sunny got back into her car and heading towards the mall.
# 3  Although her mom was obviously in love, he was nothing like her dad.
# 4           His friends were not paying attention so they believed him.
#
#                                                                                                           sentence5
# 0                                               He called a taxi to pick him up, but it took a long time to arrive.
# 1                                              He swam back to the surface and quickly paddled away from the shark.
# 2                               She went to the mall to buy a new pair of sunglasses and a hat to protect her face.
# 3                              Her mom's new husband seemed kind, but Sally noticed he was much older than her mom.
# 4  His friends were impressed by his fake shot, but they were waiting for him to get his ball out of the sand trap.
# (5000, 7)
# (40000, 5)
# (40000, 5)

# %%
# !pip install nltk rouge-score sentence-transformers -q
# Out:
#   Preparing metadata (setup.py) ... done
#   Building wheel for rouge-score (setup.py) ... done

# %%
import nltk
from rouge_score import rouge_scorer
from sentence_transformers import SentenceTransformer, util
from sklearn.metrics.pairwise import cosine_similarity
from nltk.translate.bleu_score import SmoothingFunction

import warnings
warnings.filterwarnings("ignore")

# Download the required NLTK data for BLEU
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
# Initialize sentence transformer model and rouge scorer once
scorer = rouge_scorer.RougeScorer(['rouge1', 'rouge2', 'rougeL'], use_stemmer=True)
model = SentenceTransformer('all-MiniLM-L6-v2')  # Lightweight model for embedding similarity
smoothing_fn = SmoothingFunction().method1  # Smoothing function for BLEU

def evaluate_generated_sentences(original_df, generated_df):
    # Prepare lists to store results
    bleu_scores = []
    rouge1_scores = []
    rouge2_scores = []
    rougeL_scores = []
    cosine_similarities = []

    # Evaluate each pair of sentences
    for i in range(len(original_df)):
        reference = original_df.iloc[i]['sentence5']  # Original fifth sentence
        candidate = generated_df.iloc[i]['sentence5']  # Generated fifth sentence

        # BLEU Score with smoothing
        reference_tokens = nltk.word_tokenize(reference)
        candidate_tokens = nltk.word_tokenize(candidate)
        bleu_score = nltk.translate.bleu_score.sentence_bleu([reference_tokens], candidate_tokens, smoothing_function=smoothing_fn)
        bleu_scores.append(bleu_score)

        # ROUGE Scores
        rouge_scores = scorer.score(reference, candidate)
        rouge1_scores.append(rouge_scores['rouge1'].fmeasure)
        rouge2_scores.append(rouge_scores['rouge2'].fmeasure)
        rougeL_scores.append(rouge_scores['rougeL'].fmeasure)

        # Cosine Similarity
        reference_embedding = model.encode(reference, convert_to_tensor=True)
        candidate_embedding = model.encode(candidate, convert_to_tensor=True)
        cosine_similarity_score = util.cos_sim(reference_embedding, candidate_embedding).item()
        cosine_similarities.append(cosine_similarity_score)

    # Combine results into a DataFrame
    evaluation_df = pd.DataFrame({
        'BLEU': bleu_scores,
        'ROUGE-1': rouge1_scores,
        'ROUGE-2': rouge2_scores,
        'ROUGE-L': rougeL_scores,
        'Cosine Similarity': cosine_similarities
    })

    # Display summary statistics
    print("Evaluation Summary:")
    display(evaluation_df.describe())

    return evaluation_df

# %%
# Evaluate mistral_df
mistral_evaluation = evaluate_generated_sentences(original_df, mistral_df)

# Evaluate llama_df
llama_evaluation = evaluate_generated_sentences(original_df, llama_df)
# Out:
# Evaluation Summary:
#               BLEU      ROUGE-1      ROUGE-2      ROUGE-L  Cosine Similarity
# count  5000.000000  5000.000000  5000.000000  5000.000000        5000.000000
# mean      0.023233     0.187577     0.028701     0.159544           0.441367
# std       0.029695     0.124017     0.065040     0.106868           0.189705
# min       0.000000     0.000000     0.000000     0.000000          -0.088409
# 25%       0.013401     0.095238     0.000000     0.086957           0.297143
# 50%       0.017109     0.173913     0.000000     0.148148           0.448881
# 75%       0.022417     0.260870     0.000000     0.222222           0.584294
# max       0.483270     0.888889     0.631579     0.888889           0.948432
# Evaluation Summary:
#               BLEU      ROUGE-1      ROUGE-2      ROUGE-L  Cosine Similarity
# count  5000.000000  5000.000000  5000.000000  5000.000000        5000.000000
# mean      0.020972     0.188452     0.031432     0.157655           0.434675
# std       0.026080     0.116893     0.063688     0.099519           0.176308
# min       0.000000     0.000000     0.000000     0.000000          -0.043847
# 25%       0.011713     0.095238     0.000000     0.083333           0.308418
# 50%       0.014628     0.176471     0.000000     0.148148           0.431469
# 75%       0.020448     0.260870     0.062500     0.210526           0.562460
# max       0.457883     0.727273     0.695652     0.720000           0.943182
